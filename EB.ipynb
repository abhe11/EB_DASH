# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql
conn = pymysql.connect(host='localhost', user='root', password='', db='eb')
cursor = conn.cursor()
cursor.execute('select distinct pono from master')
rows = cursor.fetchall()
for row in rows:
   print(row)
conn.commit()
conn.close()
# Out:
# (91,)
# (96,)
# (97,)
# (100,)
# (101,)
# (104,)
# (107,)
# (108,)
# (109,)
# (110,)
# (113,)
# (114,)
# (115,)
# (116,)
# (117,)
# (118,)
# (119,)
# (120,)
# (121,)
# (122,)
# (123,)

# %%
import dash
import dash_table
import pandas as pd

df = pd.read_csv('OneDrive/Desktop/New folder/data po-97/master.csv')

app = dash.Dash(__name__)

app.layout = dash_table.DataTable(
    id='table',
    columns=[{"name": i, "id": i} for i in df.columns],
    data=df.to_dict('records'),
)

if __name__ == '__main__':
    app.run_server(debug=False)

# %%
import pandas as pd
df = pd.read_csv('OneDrive/Desktop/New folder/data po-97/master.csv')
df.head(20)
# Out:
#     S_NO    NAME_OF_THE_VESSEL QUANTITY DISCHARGE_COMPLETED        PORT  pono  \
# 0      1           M.V.CORBITA    24024            24.03.14  TUTICORIN     91
# 1      2      M.V.ACS DIAMOND     52769            28.03.14  TUTICORIN     91
# 2      3              M.V.SKUA    51000            07.04.14  TUTICORIN     91
# 3      4            M.V.LUZREN    49755            05.05.14  TUTICORIN     91
# 4      5          M.V.SLETTNES    51000            15.05.14  TUTICORIN     91
# 5      6    M.V.TEN YOSHI MARU    52999            01.06.14  TUTICORIN     91
# 6      7          M.V.SEPHORA     51000            11.06.14  TUTICORIN     91
# 7      8       M.V.BULK TITAN     53024            22.06.14  TUTICORIN     91
# 8      9  M.V.GENCO PYRENESS      51000            10.07.14  TUTICORIN     91
# 9     10            M.V.PARNON    51700            12.08.14  TUTICORIN     91
# 10    11      M.V.MARE TRADER     51700            30.07.14  TUTICORIN     91
# ...

# %%
import datetime

# %%
datetime.datetime.strptime('18.9.2020', '%d.%m.%Y')
# Out:
# datetime.datetime(2020, 9, 18, 0, 0)

# %%
possible_formats = ['%d.%m.%Y', '%d.%m.%y']
for date_form in possible_formats:
    datetime.strptime()

# %%
pwd
# Out:
# 'C:\\Users\\adhi3'

# %%
dt_col = 'DISCHARGE_COMPLETED'
temp = pd.to_datetime(df[dt_col])
temp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855         try:
# -> 1856             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1857             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c37c7e8ab2f7> in <module>
#       1 dt_col = 'DISCHARGE_COMPLETED'
# ----> 2 temp = pd.to_datetime(df[dt_col])
#       3 temp
#
# ...

# %%
df['DISCHARGE_COMPLETED']=pd.to_datetime(df['DISCHARGE_COMPLETED'],format='%d.%m%.%y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-57c0421f4c84> in <module>
# ----> 1 df['DISCHARGE_COMPLETED']=pd.to_datetime(df['DISCHARGE_COMPLETED'],format='%d.%m%.%y')
#
# ...
